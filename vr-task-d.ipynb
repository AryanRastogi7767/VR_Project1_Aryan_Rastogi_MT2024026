# %%
import os
import pandas as pd
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, UpSampling2D, concatenate, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import numpy as np
from tqdm import tqdm
import matplotlib.pyplot as plt
import cv2
from sklearn.model_selection import train_test_split

# %%
DATASET_PATH = "/kaggle/input/face-mask-segmentation"

# List contents of the dataset
print("Dataset contains:", os.listdir(DATASET_PATH))

# Check folders inside the dataset
for folder in os.listdir(DATASET_PATH):
    folder_path = os.path.join(DATASET_PATH, folder)
    if os.path.isdir(folder_path):
        print(f"📂 {folder} contains:", os.listdir(folder_path))
# Out:
# Dataset contains: ['1']
# 📂 1 contains: ['face_crop_segmentation', 'face_crop', 'dataset.csv']

# %%
# Paths to dataset folders
IMAGE_DIR = "/kaggle/input/face-mask-segmentation/1/face_crop"
MASK_DIR = "/kaggle/input/face-mask-segmentation/1/face_crop_segmentation"
IMG_SIZE = (64, 64)  # Modify this to change input image size

# Load images and masks with filtering
image_filenames = set(os.listdir(IMAGE_DIR))
mask_filenames = set(os.listdir(MASK_DIR))

common_filenames = image_filenames.intersection(mask_filenames)

def load_images(filenames, img_dir, mask_dir):
    images, masks = [], []
    for file in tqdm(filenames, desc="Loading Images"):
        img_path = os.path.join(img_dir, file)
        mask_path = os.path.join(mask_dir, file)
        
        img = cv2.imread(img_path)
        mask = cv2.imread(mask_path, cv2.IMREAD_GRAYSCALE)
        
        if img is None or mask is None:
            continue
        
        img = cv2.resize(img, IMG_SIZE)
        mask = cv2.resize(mask, IMG_SIZE)
        
        img = img / 255.0
        mask = np.expand_dims(mask, axis=-1) / 255.0  # Normalize and add channel dim
        
        images.append(img)
        masks.append(mask)
    
    return np.array(images), np.array(masks)

    
    return np.array(images), np.array(masks)

images, masks = load_images(common_filenames, IMAGE_DIR, MASK_DIR)

# Split into train and test sets
X_train, X_test, y_train, y_test = train_test_split(images, masks, test_size=0.2, random_state=42)
# Out:
# Loading Images: 100%|██████████| 9382/9382 [02:57<00:00, 52.98it/s]

# %%
def unet_model(input_size=(64, 64, 3)):
    inputs = Input(input_size)
    
    # Encoder
    c1 = Conv2D(64, (3, 3), activation='relu', padding='same')(inputs)
    c1 = Conv2D(64, (3, 3), activation='relu', padding='same')(c1)
    p1 = MaxPooling2D((2, 2))(c1)
    
    c2 = Conv2D(128, (3, 3), activation='relu', padding='same')(p1)
    c2 = Conv2D(128, (3, 3), activation='relu', padding='same')(c2)
    p2 = MaxPooling2D((2, 2))(c2)
    
    c3 = Conv2D(256, (3, 3), activation='relu', padding='same')(p2)
    c3 = Conv2D(256, (3, 3), activation='relu', padding='same')(c3)
    p3 = MaxPooling2D((2, 2))(c3)
    
    c4 = Conv2D(512, (3, 3), activation='relu', padding='same')(p3)
    c4 = Conv2D(512, (3, 3), activation='relu', padding='same')(c4)
    p4 = MaxPooling2D((2, 2))(c4)
    
    # Bottleneck
    c5 = Conv2D(1024, (3, 3), activation='relu', padding='same')(p4)
    c5 = Conv2D(1024, (3, 3), activation='relu', padding='same')(c5)
    
    # Decoder
    u6 = UpSampling2D((2, 2))(c5)
    u6 = Concatenate()([u6, c4])
    c6 = Conv2D(512, (3, 3), activation='relu', padding='same')(u6)
    c6 = Conv2D(512, (3, 3), activation='relu', padding='same')(c6)
    
    u7 = UpSampling2D((2, 2))(c6)
    u7 = Concatenate()([u7, c3])
    c7 = Conv2D(256, (3, 3), activation='relu', padding='same')(u7)
    c7 = Conv2D(256, (3, 3), activation='relu', padding='same')(c7)
    
    u8 = UpSampling2D((2, 2))(c7)
    u8 = Concatenate()([u8, c2])
    c8 = Conv2D(128, (3, 3), activation='relu', padding='same')(u8)
    c8 = Conv2D(128, (3, 3), activation='relu', padding='same')(c8)
    
    u9 = UpSampling2D((2, 2))(c8)
    u9 = Concatenate()([u9, c1])
    c9 = Conv2D(64, (3, 3), activation='relu', padding='same')(u9)
    c9 = Conv2D(64, (3, 3), activation='relu', padding='same')(c9)
    
    outputs = Conv2D(1, (1, 1), activation='sigmoid')(c9)
    
    model = Model(inputs, outputs)
    model.compile(optimizer=Adam(learning_rate=1e-4), loss='binary_crossentropy', metrics=['accuracy'])
    
    return model

# Create model
model = unet_model()
model.summary()

# Train the model with validation loss & accuracy tracking
history = model.fit(
    X_train, y_train,
    validation_data=(X_test, y_test),
    batch_size=16,
    epochs=20,
    verbose=1
)


def plot_history(history):
    plt.figure(figsize=(12, 5))
    
    # Loss plot
    plt.subplot(1, 2, 1)
    plt.plot(history.history['loss'], label='Train Loss')
    plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.title('Loss Curve')
    plt.legend()
    
    # Accuracy plot
    plt.subplot(1, 2, 2)
    plt.plot(history.history['accuracy'], label='Train Accuracy')
    plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.title('Accuracy Curve')
    plt.legend()
    
    plt.show()

plot_history(history)
# Out:
# Model: "functional_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_2             │ (None, 64, 64, 3)      │              0 │ -                      │
# │ (InputLayer)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_38 (Conv2D)        │ (None, 64, 64, 64)     │          1,792 │ input_layer_2[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_39 (Conv2D)        │ (None, 64, 64, 64)     │         36,928 │ conv2d_38[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d_8           │ (None, 32, 32, 64)     │              0 │ conv2d_39[0][0]        │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_40 (Conv2D)        │ (None, 32, 32, 128)    │         73,856 │ max_pooling2d_8[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_41 (Conv2D)        │ (None, 32, 32, 128)    │        147,584 │ conv2d_40[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d_9           │ (None, 16, 16, 128)    │              0 │ conv2d_41[0][0]        │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_42 (Conv2D)        │ (None, 16, 16, 256)    │        295,168 │ max_pooling2d_9[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_43 (Conv2D)        │ (None, 16, 16, 256)    │        590,080 │ conv2d_42[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d_10          │ (None, 8, 8, 256)      │              0 │ conv2d_43[0][0]        │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_44 (Conv2D)        │ (None, 8, 8, 512)      │      1,180,160 │ max_pooling2d_10[0][0] │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_45 (Conv2D)        │ (None, 8, 8, 512)      │      2,359,808 │ conv2d_44[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d_11          │ (None, 4, 4, 512)      │              0 │ conv2d_45[0][0]        │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_46 (Conv2D)        │ (None, 4, 4, 1024)     │      4,719,616 │ max_pooling2d_11[0][0] │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_47 (Conv2D)        │ (None, 4, 4, 1024)     │      9,438,208 │ conv2d_46[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ up_sampling2d_8           │ (None, 8, 8, 1024)     │              0 │ conv2d_47[0][0]        │
# │ (UpSampling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_8             │ (None, 8, 8, 1536)     │              0 │ up_sampling2d_8[0][0], │
# │ (Concatenate)             │                        │                │ conv2d_45[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_48 (Conv2D)        │ (None, 8, 8, 512)      │      7,078,400 │ concatenate_8[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_49 (Conv2D)        │ (None, 8, 8, 512)      │      2,359,808 │ conv2d_48[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ up_sampling2d_9           │ (None, 16, 16, 512)    │              0 │ conv2d_49[0][0]        │
# │ (UpSampling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_9             │ (None, 16, 16, 768)    │              0 │ up_sampling2d_9[0][0], │
# │ (Concatenate)             │                        │                │ conv2d_43[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_50 (Conv2D)        │ (None, 16, 16, 256)    │      1,769,728 │ concatenate_9[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_51 (Conv2D)        │ (None, 16, 16, 256)    │        590,080 │ conv2d_50[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ up_sampling2d_10          │ (None, 32, 32, 256)    │              0 │ conv2d_51[0][0]        │
# │ (UpSampling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_10            │ (None, 32, 32, 384)    │              0 │ up_sampling2d_10[0][0… │
# │ (Concatenate)             │                        │                │ conv2d_41[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_52 (Conv2D)        │ (None, 32, 32, 128)    │        442,496 │ concatenate_10[0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_53 (Conv2D)        │ (None, 32, 32, 128)    │        147,584 │ conv2d_52[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ up_sampling2d_11          │ (None, 64, 64, 128)    │              0 │ conv2d_53[0][0]        │
# │ (UpSampling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_11            │ (None, 64, 64, 192)    │              0 │ up_sampling2d_11[0][0… │
# │ (Concatenate)             │                        │                │ conv2d_39[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_54 (Conv2D)        │ (None, 64, 64, 64)     │        110,656 │ concatenate_11[0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_55 (Conv2D)        │ (None, 64, 64, 64)     │         36,928 │ conv2d_54[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_56 (Conv2D)        │ (None, 64, 64, 1)      │             65 │ conv2d_55[0][0]        │
# └───────────────────────────┴────────────────────────┴────────────────┴────────────────────────┘
#  Total params: 31,378,945 (119.70 MB)
#  Trainable params: 31,378,945 (119.70 MB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/20
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 98s 146ms/step - accuracy: 0.5803 - loss: 0.3025 - val_accuracy: 0.6147 - val_loss: 0.1396
# Epoch 2/20
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 52s 98ms/step - accuracy: 0.6067 - loss: 0.1375 - val_accuracy: 0.6197 - val_loss: 0.1166
# Epoch 3/20
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 51s 97ms/step - accuracy: 0.6093 - loss: 0.1088 - val_accuracy: 0.6196 - val_loss: 0.1061
# Epoch 4/20
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 52s 98ms/step - accuracy: 0.6128 - loss: 0.0981 - val_accuracy: 0.6166 - val_loss: 0.0997
# Epoch 5/20
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 51s 97ms/step - accuracy: 0.6128 - loss: 0.0880 - val_accuracy: 0.6207 - val_loss: 0.0882
# Epoch 6/20
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 51s 97ms/step - accuracy: 0.6156 - loss: 0.0807 - val_accuracy: 0.6202 - val_loss: 0.0890
# Epoch 7/20
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 51s 97ms/step - accuracy: 0.6152 - loss: 0.0745 - val_accuracy: 0.6211 - val_loss: 0.0840
# Epoch 8/20
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 51s 96ms/step - accuracy: 0.6162 - loss: 0.0711 - val_accuracy: 0.6203 - val_loss: 0.0859
# Epoch 9/20
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 51s 96ms/step - accuracy: 0.6151 - loss: 0.0681 - val_accuracy: 0.6220 - val_loss: 0.0834
# Epoch 10/20
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 51s 96ms/step - accuracy: 0.6159 - loss: 0.0647 - val_accuracy: 0.6210 - val_loss: 0.0838
# Epoch 11/20
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 51s 96ms/step - accuracy: 0.6164 - loss: 0.0609 - val_accuracy: 0.6226 - val_loss: 0.0783
# Epoch 12/20
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 51s 96ms/step - accuracy: 0.6160 - loss: 0.0603 - val_accuracy: 0.6221 - val_loss: 0.0787
# Epoch 13/20
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 51s 96ms/step - accuracy: 0.6189 - loss: 0.0574 - val_accuracy: 0.6219 - val_loss: 0.0800
# Epoch 14/20
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 51s 96ms/step - accuracy: 0.6180 - loss: 0.0586 - val_accuracy: 0.6230 - val_loss: 0.0781
# Epoch 15/20
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 51s 96ms/step - accuracy: 0.6186 - loss: 0.0550 - val_accuracy: 0.6221 - val_loss: 0.0800
# Epoch 16/20
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 51s 96ms/step - accuracy: 0.6172 - loss: 0.0529 - val_accuracy: 0.6230 - val_loss: 0.0774
# Epoch 17/20
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 51s 97ms/step - accuracy: 0.6170 - loss: 0.0511 - val_accuracy: 0.6227 - val_loss: 0.0773
# Epoch 18/20
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 51s 97ms/step - accuracy: 0.6185 - loss: 0.0507 - val_accuracy: 0.6220 - val_loss: 0.0787
# Epoch 19/20
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 51s 97ms/step - accuracy: 0.6186 - loss: 0.0518 - val_accuracy: 0.6229 - val_loss: 0.0771
# Epoch 20/20
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 51s 97ms/step - accuracy: 0.6178 - loss: 0.0495 - val_accuracy: 0.6221 - val_loss: 0.0790

# %%
train_dataset = tf.data.Dataset.from_tensor_slices((X_train, y_train))
test_dataset = tf.data.Dataset.from_tensor_slices((X_test, y_test))

# Batch the datasets
batch_size = 32
train_dataset = train_dataset.batch(batch_size)
test_dataset = test_dataset.batch(batch_size)

# Prefetch for better performance
train_dataset = train_dataset.prefetch(tf.data.experimental.AUTOTUNE)
test_dataset = test_dataset.prefetch(tf.data.experimental.AUTOTUNE)

# %%
#metrics
def iou_metric(y_true, y_pred, smooth=1):
    y_true = tf.cast(y_true, tf.float32)  
    y_pred = tf.cast(y_pred, tf.float32)  
    intersection = tf.reduce_sum(y_true * y_pred)
    union = tf.reduce_sum(y_true) + tf.reduce_sum(y_pred) - intersection
    return (intersection + smooth) / (union + smooth)

def dice_coefficient(y_true, y_pred, smooth=1):
    y_true = tf.cast(y_true, tf.float32) 
    y_pred = tf.cast(y_pred, tf.float32) 
    intersection = tf.reduce_sum(y_true * y_pred)
    return (2 * intersection + smooth) / (tf.reduce_sum(y_true) + tf.reduce_sum(y_pred) + smooth)

# %%
def unet(input_size=(64, 64, 3)):
    inputs = Input(input_size)
    
    # Encoder
    conv1 = Conv2D(64, (3, 3), activation='relu', padding='same')(inputs)
    conv1 = Conv2D(64, (3, 3), activation='relu', padding='same')(conv1)
    pool1 = MaxPooling2D((2, 2))(conv1)
    pool1 = Dropout(0.2)(pool1)  # Dropout for regularization

    conv2 = Conv2D(128, (3, 3), activation='relu', padding='same')(pool1)
    conv2 = Conv2D(128, (3, 3), activation='relu', padding='same')(conv2)
    pool2 = MaxPooling2D((2, 2))(conv2)
    pool2 = Dropout(0.2)(pool2)

    # Bottleneck
    conv3 = Conv2D(256, (3, 3), activation='relu', padding='same')(pool2)
    conv3 = Conv2D(256, (3, 3), activation='relu', padding='same')(conv3)

    # Decoder
    up1 = UpSampling2D((2, 2))(conv3)
    up1 = concatenate([up1, conv2], axis=-1)
    up1 = Dropout(0.2)(up1)
    conv4 = Conv2D(128, (3, 3), activation='relu', padding='same')(up1)
    conv4 = Conv2D(128, (3, 3), activation='relu', padding='same')(conv4)

    up2 = UpSampling2D((2, 2))(conv4)
    up2 = concatenate([up2, conv1], axis=-1)
    up2 = Dropout(0.2)(up2)
    conv5 = Conv2D(64, (3, 3), activation='relu', padding='same')(up2)
    conv5 = Conv2D(64, (3, 3), activation='relu', padding='same')(conv5)

    # Output
    outputs = Conv2D(1, (1, 1), activation='sigmoid')(conv5)  # Binary segmentation

    model = Model(inputs, outputs)
    return model

# Check available GPUs
gpus = tf.config.list_physical_devices('GPU')
print(f"Available GPUs: {gpus}")

# Use MirroredStrategy for multi-GPU training
strategy = tf.distribute.MirroredStrategy()

# Define the model and compile it within the strategy scope
with strategy.scope():
    model = unet(input_size=(64, 64, 3))
    model.compile(optimizer=Adam(learning_rate=1e-4), loss='binary_crossentropy', metrics=['accuracy', iou_metric, dice_coefficient])

# Callbacks
early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=3, min_lr=1e-6)

# Train the model
history = model.fit(
    train_dataset,
    validation_data=test_dataset,
    epochs=100,
    callbacks=[early_stopping, reduce_lr],
    verbose=1
)
# Out:
# Available GPUs: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU'), PhysicalDevice(name='/physical_device:GPU:1', device_type='GPU')]
# Epoch 1/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 27s 72ms/step - accuracy: 0.5694 - dice_coefficient: 0.5131 - iou_metric: 0.3553 - loss: 0.4838 - val_accuracy: 0.5377 - val_dice_coefficient: 0.7476 - val_iou_metric: 0.5974 - val_loss: 0.3112 - learning_rate: 1.0000e-04
# Epoch 2/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 15s 61ms/step - accuracy: 0.5904 - dice_coefficient: 0.7794 - iou_metric: 0.6393 - loss: 0.2298 - val_accuracy: 0.5648 - val_dice_coefficient: 0.8079 - val_iou_metric: 0.6781 - val_loss: 0.2359 - learning_rate: 1.0000e-04
# Epoch 3/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 15s 62ms/step - accuracy: 0.5976 - dice_coefficient: 0.8258 - iou_metric: 0.7038 - loss: 0.1852 - val_accuracy: 0.5873 - val_dice_coefficient: 0.8485 - val_iou_metric: 0.7374 - val_loss: 0.1790 - learning_rate: 1.0000e-04
# Epoch 4/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 16s 63ms/step - accuracy: 0.6017 - dice_coefficient: 0.8505 - iou_metric: 0.7403 - loss: 0.1614 - val_accuracy: 0.5874 - val_dice_coefficient: 0.8611 - val_iou_metric: 0.7566 - val_loss: 0.1743 - learning_rate: 1.0000e-04
# Epoch 5/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 16s 62ms/step - accuracy: 0.6040 - dice_coefficient: 0.8658 - iou_metric: 0.7639 - loss: 0.1460 - val_accuracy: 0.5925 - val_dice_coefficient: 0.8727 - val_iou_metric: 0.7747 - val_loss: 0.1605 - learning_rate: 1.0000e-04
# Epoch 6/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 16s 63ms/step - accuracy: 0.6056 - dice_coefficient: 0.8762 - iou_metric: 0.7801 - loss: 0.1356 - val_accuracy: 0.5981 - val_dice_coefficient: 0.8826 - val_iou_metric: 0.7904 - val_loss: 0.1443 - learning_rate: 1.0000e-04
# Epoch 7/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 16s 64ms/step - accuracy: 0.6067 - dice_coefficient: 0.8839 - iou_metric: 0.7924 - loss: 0.1278 - val_accuracy: 0.6017 - val_dice_coefficient: 0.8891 - val_iou_metric: 0.8008 - val_loss: 0.1343 - learning_rate: 1.0000e-04
# Epoch 8/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 16s 65ms/step - accuracy: 0.6076 - dice_coefficient: 0.8898 - iou_metric: 0.8020 - loss: 0.1217 - val_accuracy: 0.6059 - val_dice_coefficient: 0.8956 - val_iou_metric: 0.8115 - val_loss: 0.1222 - learning_rate: 1.0000e-04
# Epoch 9/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 16s 64ms/step - accuracy: 0.6082 - dice_coefficient: 0.8940 - iou_metric: 0.8088 - loss: 0.1173 - val_accuracy: 0.6080 - val_dice_coefficient: 0.8997 - val_iou_metric: 0.8182 - val_loss: 0.1151 - learning_rate: 1.0000e-04
# Epoch 10/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 16s 64ms/step - accuracy: 0.6087 - dice_coefficient: 0.8978 - iou_metric: 0.8150 - loss: 0.1133 - val_accuracy: 0.6099 - val_dice_coefficient: 0.9030 - val_iou_metric: 0.8236 - val_loss: 0.1098 - learning_rate: 1.0000e-04
# Epoch 11/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 16s 64ms/step - accuracy: 0.6093 - dice_coefficient: 0.9009 - iou_metric: 0.8201 - loss: 0.1101 - val_accuracy: 0.6109 - val_dice_coefficient: 0.9061 - val_iou_metric: 0.8288 - val_loss: 0.1063 - learning_rate: 1.0000e-04
# Epoch 12/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 16s 64ms/step - accuracy: 0.6097 - dice_coefficient: 0.9040 - iou_metric: 0.8253 - loss: 0.1068 - val_accuracy: 0.6122 - val_dice_coefficient: 0.9088 - val_iou_metric: 0.8332 - val_loss: 0.1029 - learning_rate: 1.0000e-04
# Epoch 13/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 16s 64ms/step - accuracy: 0.6102 - dice_coefficient: 0.9067 - iou_metric: 0.8298 - loss: 0.1039 - val_accuracy: 0.6125 - val_dice_coefficient: 0.9106 - val_iou_metric: 0.8363 - val_loss: 0.1014 - learning_rate: 1.0000e-04
# Epoch 14/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 16s 64ms/step - accuracy: 0.6106 - dice_coefficient: 0.9091 - iou_metric: 0.8338 - loss: 0.1015 - val_accuracy: 0.6125 - val_dice_coefficient: 0.9124 - val_iou_metric: 0.8393 - val_loss: 0.1005 - learning_rate: 1.0000e-04
# Epoch 15/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 16s 64ms/step - accuracy: 0.6108 - dice_coefficient: 0.9105 - iou_metric: 0.8362 - loss: 0.1000 - val_accuracy: 0.6120 - val_dice_coefficient: 0.9126 - val_iou_metric: 0.8397 - val_loss: 0.1003 - learning_rate: 1.0000e-04
# Epoch 16/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 16s 64ms/step - accuracy: 0.6112 - dice_coefficient: 0.9128 - iou_metric: 0.8400 - loss: 0.0976 - val_accuracy: 0.6128 - val_dice_coefficient: 0.9152 - val_iou_metric: 0.8441 - val_loss: 0.0985 - learning_rate: 1.0000e-04
# Epoch 17/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 16s 64ms/step - accuracy: 0.6113 - dice_coefficient: 0.9147 - iou_metric: 0.8432 - loss: 0.0956 - val_accuracy: 0.6120 - val_dice_coefficient: 0.9156 - val_iou_metric: 0.8448 - val_loss: 0.0980 - learning_rate: 1.0000e-04
# Epoch 18/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 16s 64ms/step - accuracy: 0.6116 - dice_coefficient: 0.9161 - iou_metric: 0.8455 - loss: 0.0940 - val_accuracy: 0.6134 - val_dice_coefficient: 0.9167 - val_iou_metric: 0.8466 - val_loss: 0.0961 - learning_rate: 1.0000e-04
# Epoch 19/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 16s 63ms/step - accuracy: 0.6118 - dice_coefficient: 0.9174 - iou_metric: 0.8477 - loss: 0.0927 - val_accuracy: 0.6135 - val_dice_coefficient: 0.9167 - val_iou_metric: 0.8467 - val_loss: 0.0954 - learning_rate: 1.0000e-04
# Epoch 20/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 16s 64ms/step - accuracy: 0.6121 - dice_coefficient: 0.9191 - iou_metric: 0.8507 - loss: 0.0905 - val_accuracy: 0.6132 - val_dice_coefficient: 0.9185 - val_iou_metric: 0.8497 - val_loss: 0.0950 - learning_rate: 1.0000e-04
# Epoch 21/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 16s 64ms/step - accuracy: 0.6123 - dice_coefficient: 0.9205 - iou_metric: 0.8530 - loss: 0.0894 - val_accuracy: 0.6140 - val_dice_coefficient: 0.9196 - val_iou_metric: 0.8516 - val_loss: 0.0943 - learning_rate: 1.0000e-04
# Epoch 22/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 16s 64ms/step - accuracy: 0.6126 - dice_coefficient: 0.9222 - iou_metric: 0.8560 - loss: 0.0875 - val_accuracy: 0.6125 - val_dice_coefficient: 0.9186 - val_iou_metric: 0.8498 - val_loss: 0.0965 - learning_rate: 1.0000e-04
# Epoch 23/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 16s 64ms/step - accuracy: 0.6126 - dice_coefficient: 0.9224 - iou_metric: 0.8564 - loss: 0.0875 - val_accuracy: 0.6124 - val_dice_coefficient: 0.9200 - val_iou_metric: 0.8523 - val_loss: 0.0959 - learning_rate: 1.0000e-04
# Epoch 24/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 16s 64ms/step - accuracy: 0.6129 - dice_coefficient: 0.9238 - iou_metric: 0.8586 - loss: 0.0859 - val_accuracy: 0.6134 - val_dice_coefficient: 0.9209 - val_iou_metric: 0.8538 - val_loss: 0.0941 - learning_rate: 1.0000e-04
# Epoch 25/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 16s 64ms/step - accuracy: 0.6130 - dice_coefficient: 0.9250 - iou_metric: 0.8607 - loss: 0.0846 - val_accuracy: 0.6136 - val_dice_coefficient: 0.9225 - val_iou_metric: 0.8565 - val_loss: 0.0933 - learning_rate: 1.0000e-04
# Epoch 26/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 16s 64ms/step - accuracy: 0.6131 - dice_coefficient: 0.9262 - iou_metric: 0.8628 - loss: 0.0834 - val_accuracy: 0.6135 - val_dice_coefficient: 0.9243 - val_iou_metric: 0.8597 - val_loss: 0.0940 - learning_rate: 1.0000e-04
# Epoch 27/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 16s 64ms/step - accuracy: 0.6133 - dice_coefficient: 0.9273 - iou_metric: 0.8647 - loss: 0.0823 - val_accuracy: 0.6147 - val_dice_coefficient: 0.9249 - val_iou_metric: 0.8607 - val_loss: 0.0922 - learning_rate: 1.0000e-04
# Epoch 28/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 16s 64ms/step - accuracy: 0.6136 - dice_coefficient: 0.9288 - iou_metric: 0.8673 - loss: 0.0807 - val_accuracy: 0.6130 - val_dice_coefficient: 0.9244 - val_iou_metric: 0.8598 - val_loss: 0.0950 - learning_rate: 1.0000e-04
# Epoch 29/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 16s 64ms/step - accuracy: 0.6138 - dice_coefficient: 0.9300 - iou_metric: 0.8693 - loss: 0.0796 - val_accuracy: 0.6151 - val_dice_coefficient: 0.9265 - val_iou_metric: 0.8635 - val_loss: 0.0906 - learning_rate: 1.0000e-04
# Epoch 30/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 16s 64ms/step - accuracy: 0.6138 - dice_coefficient: 0.9301 - iou_metric: 0.8696 - loss: 0.0795 - val_accuracy: 0.6153 - val_dice_coefficient: 0.9284 - val_iou_metric: 0.8669 - val_loss: 0.0914 - learning_rate: 1.0000e-04
# Epoch 31/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 16s 64ms/step - accuracy: 0.6141 - dice_coefficient: 0.9323 - iou_metric: 0.8734 - loss: 0.0772 - val_accuracy: 0.6149 - val_dice_coefficient: 0.9278 - val_iou_metric: 0.8657 - val_loss: 0.0914 - learning_rate: 1.0000e-04
# Epoch 32/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 16s 64ms/step - accuracy: 0.6142 - dice_coefficient: 0.9328 - iou_metric: 0.8742 - loss: 0.0767 - val_accuracy: 0.6156 - val_dice_coefficient: 0.9279 - val_iou_metric: 0.8659 - val_loss: 0.0901 - learning_rate: 1.0000e-04
# Epoch 33/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 16s 64ms/step - accuracy: 0.6145 - dice_coefficient: 0.9342 - iou_metric: 0.8767 - loss: 0.0752 - val_accuracy: 0.6166 - val_dice_coefficient: 0.9274 - val_iou_metric: 0.8651 - val_loss: 0.0911 - learning_rate: 1.0000e-04
# Epoch 34/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 16s 64ms/step - accuracy: 0.6147 - dice_coefficient: 0.9357 - iou_metric: 0.8793 - loss: 0.0737 - val_accuracy: 0.6155 - val_dice_coefficient: 0.9285 - val_iou_metric: 0.8670 - val_loss: 0.0910 - learning_rate: 1.0000e-04
# Epoch 35/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 16s 63ms/step - accuracy: 0.6149 - dice_coefficient: 0.9368 - iou_metric: 0.8813 - loss: 0.0724 - val_accuracy: 0.6159 - val_dice_coefficient: 0.9286 - val_iou_metric: 0.8672 - val_loss: 0.0928 - learning_rate: 1.0000e-04
# Epoch 36/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 16s 64ms/step - accuracy: 0.6151 - dice_coefficient: 0.9382 - iou_metric: 0.8838 - loss: 0.0707 - val_accuracy: 0.6163 - val_dice_coefficient: 0.9334 - val_iou_metric: 0.8755 - val_loss: 0.0886 - learning_rate: 2.0000e-05
# Epoch 37/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 16s 64ms/step - accuracy: 0.6155 - dice_coefficient: 0.9401 - iou_metric: 0.8872 - loss: 0.0690 - val_accuracy: 0.6165 - val_dice_coefficient: 0.9337 - val_iou_metric: 0.8761 - val_loss: 0.0882 - learning_rate: 2.0000e-05
# Epoch 38/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 16s 64ms/step - accuracy: 0.6155 - dice_coefficient: 0.9405 - iou_metric: 0.8878 - loss: 0.0686 - val_accuracy: 0.6168 - val_dice_coefficient: 0.9336 - val_iou_metric: 0.8759 - val_loss: 0.0883 - learning_rate: 2.0000e-05
# Epoch 39/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 16s 64ms/step - accuracy: 0.6156 - dice_coefficient: 0.9407 - iou_metric: 0.8882 - loss: 0.0683 - val_accuracy: 0.6164 - val_dice_coefficient: 0.9341 - val_iou_metric: 0.8768 - val_loss: 0.0886 - learning_rate: 2.0000e-05
# Epoch 40/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 16s 64ms/step - accuracy: 0.6157 - dice_coefficient: 0.9416 - iou_metric: 0.8898 - loss: 0.0675 - val_accuracy: 0.6168 - val_dice_coefficient: 0.9337 - val_iou_metric: 0.8760 - val_loss: 0.0881 - learning_rate: 2.0000e-05
# Epoch 41/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 16s 64ms/step - accuracy: 0.6158 - dice_coefficient: 0.9420 - iou_metric: 0.8906 - loss: 0.0669 - val_accuracy: 0.6171 - val_dice_coefficient: 0.9335 - val_iou_metric: 0.8757 - val_loss: 0.0877 - learning_rate: 4.0000e-06
# Epoch 42/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 16s 64ms/step - accuracy: 0.6158 - dice_coefficient: 0.9425 - iou_metric: 0.8915 - loss: 0.0665 - val_accuracy: 0.6170 - val_dice_coefficient: 0.9339 - val_iou_metric: 0.8763 - val_loss: 0.0879 - learning_rate: 4.0000e-06
# Epoch 43/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 16s 63ms/step - accuracy: 0.6159 - dice_coefficient: 0.9427 - iou_metric: 0.8917 - loss: 0.0665 - val_accuracy: 0.6169 - val_dice_coefficient: 0.9339 - val_iou_metric: 0.8763 - val_loss: 0.0876 - learning_rate: 4.0000e-06
# Epoch 44/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 16s 64ms/step - accuracy: 0.6159 - dice_coefficient: 0.9430 - iou_metric: 0.8923 - loss: 0.0659 - val_accuracy: 0.6170 - val_dice_coefficient: 0.9340 - val_iou_metric: 0.8765 - val_loss: 0.0876 - learning_rate: 4.0000e-06
# Epoch 45/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 16s 63ms/step - accuracy: 0.6159 - dice_coefficient: 0.9429 - iou_metric: 0.8922 - loss: 0.0660 - val_accuracy: 0.6172 - val_dice_coefficient: 0.9339 - val_iou_metric: 0.8763 - val_loss: 0.0879 - learning_rate: 4.0000e-06
# Epoch 46/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 16s 64ms/step - accuracy: 0.6160 - dice_coefficient: 0.9432 - iou_metric: 0.8926 - loss: 0.0658 - val_accuracy: 0.6171 - val_dice_coefficient: 0.9338 - val_iou_metric: 0.8763 - val_loss: 0.0878 - learning_rate: 4.0000e-06
# Epoch 47/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 16s 64ms/step - accuracy: 0.6160 - dice_coefficient: 0.9430 - iou_metric: 0.8923 - loss: 0.0658 - val_accuracy: 0.6170 - val_dice_coefficient: 0.9339 - val_iou_metric: 0.8764 - val_loss: 0.0875 - learning_rate: 1.0000e-06
# Epoch 48/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 16s 64ms/step - accuracy: 0.6159 - dice_coefficient: 0.9431 - iou_metric: 0.8925 - loss: 0.0658 - val_accuracy: 0.6170 - val_dice_coefficient: 0.9339 - val_iou_metric: 0.8764 - val_loss: 0.0877 - learning_rate: 1.0000e-06
# Epoch 49/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 16s 63ms/step - accuracy: 0.6159 - dice_coefficient: 0.9432 - iou_metric: 0.8926 - loss: 0.0657 - val_accuracy: 0.6171 - val_dice_coefficient: 0.9338 - val_iou_metric: 0.8762 - val_loss: 0.0877 - learning_rate: 1.0000e-06
# Epoch 50/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 16s 64ms/step - accuracy: 0.6160 - dice_coefficient: 0.9430 - iou_metric: 0.8923 - loss: 0.0658 - val_accuracy: 0.6170 - val_dice_coefficient: 0.9338 - val_iou_metric: 0.8762 - val_loss: 0.0877 - learning_rate: 1.0000e-06
# Epoch 51/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 16s 63ms/step - accuracy: 0.6159 - dice_coefficient: 0.9431 - iou_metric: 0.8925 - loss: 0.0658 - val_accuracy: 0.6170 - val_dice_coefficient: 0.9339 - val_iou_metric: 0.8764 - val_loss: 0.0878 - learning_rate: 1.0000e-06
# Epoch 52/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 16s 63ms/step - accuracy: 0.6160 - dice_coefficient: 0.9433 - iou_metric: 0.8929 - loss: 0.0655 - val_accuracy: 0.6170 - val_dice_coefficient: 0.9339 - val_iou_metric: 0.8764 - val_loss: 0.0877 - learning_rate: 1.0000e-06

# %%
print(f"X_train shape: {X_train.shape}")
print(f"y_train shape: {y_train.shape}")
print(f"X_test shape: {X_test.shape}")
print(f"y_test shape: {y_test.shape}")
# Out:
# X_train shape: (8443, 64, 64, 3)
# y_train shape: (8443, 64, 64, 1)
# X_test shape: (939, 64, 64, 3)
# y_test shape: (939, 64, 64, 1)

# %%
import matplotlib.pyplot as plt

def visualize_predictions(images, masks, predictions, num_samples=10):
    plt.figure(figsize=(15, 10))
    for i in range(num_samples):
        # Display image
        plt.subplot(num_samples, 3, i * 3 + 1)
        plt.imshow(images[i])
        plt.title("Image")
        plt.axis("off")

        # Display ground truth mask
        plt.subplot(num_samples, 3, i * 3 + 2)
        plt.imshow(masks[i], cmap="gray")
        plt.title("Ground Truth Mask")
        plt.axis("off")

        # Display predicted mask
        plt.subplot(num_samples, 3, i * 3 + 3)
        plt.imshow(predictions[i], cmap="gray")
        plt.title("Predicted Mask")
        plt.axis("off")

    plt.show()

# Generate predictions
predictions = model.predict(X_test)

# Visualize predictions
visualize_predictions(X_test, y_test, predictions)
# Out:
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step
